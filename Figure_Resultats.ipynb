# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import patches

# %%
import numpy as np

a = np.array([[0,1]])
plt.figure(figsize=(9, 1.0))
img = plt.imshow(a, cmap="jet")
plt.gca().set_visible(False)
cax = plt.axes([0.1, 0.2, 0.8, 0.6])
cbar=plt.colorbar(orientation="horizontal",cax=cax,)
#plt.xticks([0,0.5,1.0],["Faible", "Moyen", "Élevé"])
plt.xticks(None)
cbar.set_ticks([])
plt.text(0.01,0.40,"Faible",fontsize=16,fontweight="bold", color="white")
plt.text(0.45,0.40,"Moyen",fontsize=16,fontweight="bold",color="black")
plt.text(0.90,0.40,"Élevé",fontsize=16,fontweight="bold",color="white")
plt.savefig("Resultats/colorbar.png", dpi=200)

# %%
Nx=1501
Lx = 40
# Espace entre chaque noeud
dx = (Lx) / (Nx - 1)

# Nombre de points en y
Ny = Nx
# Longueur en x (m)
Ly = Lx
# Espace entre chaque noeud
dy = dx
h=dx
# Épaisseur (en points de la couche de PML)
N_PML = 10

centre_bois_x = int(Nx / 2)  # 65
centre_bois_y = int(1.3 * Nx / 2)  # 600#60
# Longueur en x,y du bois (en points)
Nx_Bois = int(5 / dx)
Ny_Bois = int(10 / dx)

# Emplacement de la source
S_x = int(Nx/2)
S_y = 75

# %% [markdown]
# # Pour les carrés

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Rectangle5_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,(NxM+Nx_Bois)/2],(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"A)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Rectangle5-10_250Hz.png",dpi=200,bbox_inches="tight")

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Rectangle5_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,(NxM+Nx_Bois)/2],(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"B)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Rectangle5-10_2500Hz.png",dpi=200,bbox_inches="tight")

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Rectangle7p5_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

plt.fill_between([(NxM-1.5*Nx_Bois)/2,(NxM+1.5*Nx_Bois)/2],(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"C)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Rectangle7p5-10_250Hz.png",dpi=200,bbox_inches="tight")

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Rectangle7p5_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

plt.fill_between([(NxM-1.5*Nx_Bois)/2,(NxM+1.5*Nx_Bois)/2],(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"D)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Rectangle7p5-10_2500Hz.png",dpi=200,bbox_inches="tight")

# %% [markdown]
# # Triangle

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Triangle_pi4_1501_f250Hz_SER0.2732389635415355.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")#-np.log10(np.real(data)-(1.1*np.min(np.real(data))))
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,NxM/2,(NxM+Nx_Bois)/2],[(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)-(Ny_Bois)-14,(centre_bois_y-2*N_PML)-(Ny_Bois)/2],\
                 (centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
#plt.savefig("Resultats/Triangle_pi4_2000Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Triangle_pi2p5_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]

plt.imshow(np.real(data), cmap="jet")#-np.log10(np.real(data)-(1.1*np.min(np.real(data))))
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,NxM/2,(NxM+Nx_Bois)/2],[(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)-(Ny_Bois)+70,(centre_bois_y-2*N_PML)-(Ny_Bois)/2],\
                 (centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"A)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Triangle_pi2p5_250Hz.png",dpi=200,bbox_inches="tight")

# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Triangle_pi2p5_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]

plt.imshow(np.real(data), cmap="jet")#-np.log10(np.real(data)-(1.1*np.min(np.real(data))))
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,NxM/2,(NxM+Nx_Bois)/2],[(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)-(Ny_Bois)+70,(centre_bois_y-2*N_PML)-(Ny_Bois)/2],\
                 (centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"B)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Triangle_pi2p5_2500Hz.png",dpi=200,bbox_inches="tight")

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Triangle_pi4_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]

plt.imshow(np.real(data), cmap="jet")#-np.log10(np.real(data)-(1.1*np.min(np.real(data))))
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,NxM/2,(NxM+Nx_Bois)/2],[(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)-(Ny_Bois)-14,(centre_bois_y-2*N_PML)-(Ny_Bois)/2],\
                 (centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"C)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Triangle_pi4_250Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Triangle_pi4_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]

plt.imshow(np.real(data), cmap="jet")#-np.log10(np.real(data)-(1.1*np.min(np.real(data))))
NxM=Nx-2*N_PML
plt.fill_between([(NxM-Nx_Bois)/2,NxM/2,(NxM+Nx_Bois)/2],[(centre_bois_y-2*N_PML)-(Ny_Bois)/2,(centre_bois_y-2*N_PML)-(Ny_Bois)-14,(centre_bois_y-2*N_PML)-(Ny_Bois)/2],\
                 (centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")
plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()
ax.add_artist(circle)
plt.text(1350,1400,"D)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Triangle_pi4_2500Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.

# %% [markdown]
# # Cercle

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Cercle1p5_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

centre_y = centre_bois_y-N_PML - Ny_Bois/2 
print(centre_y)
rayon=1.5*Nx_Bois/2
centre_x=centre_bois_x-N_PML

x=np.arange(centre_x-Nx_Bois/2,centre_x+Nx_Bois/2+1)
y=-np.sqrt(rayon**2-(x-centre_x)**2)+centre_y+115



plt.fill_between(x,y,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")


plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()

ax.add_artist(circle)

plt.text(1350,1400,"A)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Cercle_1.5_250Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.
# Out:
# 777.5

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Cercle1p5_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

centre_y = centre_bois_y-N_PML - Ny_Bois/2 
print(centre_y)
rayon=1.5*Nx_Bois/2
centre_x=centre_bois_x-N_PML

x=np.arange(centre_x-Nx_Bois/2,centre_x+Nx_Bois/2+1)
y=-np.sqrt(rayon**2-(x-centre_x)**2)+centre_y+115



plt.fill_between(x,y,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")


plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()

ax.add_artist(circle)

plt.text(1350,1400,"B)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Cercle_1.5_2500Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.
# Out:
# 777.5

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Cercle2p2_250Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

centre_y = centre_bois_y-N_PML - Ny_Bois/2 
print(centre_y)
rayon=2.2*Nx_Bois/2
centre_x=centre_bois_x-N_PML

x=np.arange(centre_x-Nx_Bois/2,centre_x+Nx_Bois/2+1)
y=-np.sqrt(rayon**2-(x-centre_x)**2)+centre_y+185


plt.fill_between(x,y,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")


plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()

ax.add_artist(circle)

plt.text(1350,1400,"C)",fontsize=14, fontweight="bold")

plt.savefig("Resultats/Cercle_2.2_250Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.
# Out:
# 777.5

# %%
data=np.transpose(np.load("Resultats/Matrices_Champ/Cercle2p2_2500Hz.npy"))[N_PML:-N_PML,N_PML:-N_PML]
plt.imshow(np.real(data), cmap="jet")
NxM=Nx-2*N_PML

centre_y = centre_bois_y-N_PML - Ny_Bois/2 
print(centre_y)
rayon=2.2*Nx_Bois/2
centre_x=centre_bois_x-N_PML

x=np.arange(centre_x-Nx_Bois/2,centre_x+Nx_Bois/2+1)
y=-np.sqrt(rayon**2-(x-centre_x)**2)+centre_y+185



plt.fill_between(x,y,(centre_bois_y-2*N_PML)+(Ny_Bois)/2, edgecolor="black",\
                lw=3,facecolor="gray",hatch="o")


plt.xticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.yticks(np.arange(0,NxM,200),np.arange(0,NxM*dx,5,dtype=np.int), fontsize=12)
plt.xlabel("x (en m.)", fontsize=12, fontweight="bold")
plt.ylabel("y (en m.)", fontsize=12, fontweight="bold")
patches.Circle((10,10),radius=100)
circle=plt.Circle((S_x-N_PML,S_y-N_PML),1/dx,color="r",fill=False)
ax=plt.gca()

ax.add_artist(circle)

plt.text(1350,1400,"D)",fontsize=14, fontweight="bold")
plt.savefig("Resultats/Cercle_2.2_2500Hz.png",dpi=200,bbox_inches="tight")
# ax2 = plt.axes([0.7, 0.55, 0.155, 0.32],)
# ax2.
# Out:
# 777.5

# %% [markdown]
# # Bateau rectangle

# %%
data_carre=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_Carre.npy")
data_rectangle=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_Rectangle.npy")
data_rectangle2=np.load("Resultats/Matrices_Champ/SER/SERV2/SER_rectangle7p5x10.npy")
omega=np.load("Resultats/Matrices_Champ/SER/SERV2/Omega1001_cercle_10.npy")

# %%
plt.figure(figsize=(9,3))
#plt.plot(omega/2/np.pi,data_carre, lw=3,label="Bateau carré: 10 m x 10 m", color="blue")
plt.plot(omega/2/np.pi,data_rectangle,lw=3, ls="-", label="Bateau rectangulaire: 5 m x 10 m", color="orange")
plt.plot(omega/2/np.pi,data_rectangle2,lw=3, ls="-", label="Bateau rectangulaire: 7.5 m x 10 m", color="blue")
plt.xlabel("Fréquence(Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)

#plt.hlines(np.mean(data_carre),0,10000,label="SER moyen: Bateau carré",linestyle="--", color="blue")
plt.hlines(np.mean(data_rectangle),0,10000,label="SER moyenne: Bateau rectangulaire 5x10",linestyle="--", color="orange")
plt.hlines(np.mean(data_rectangle2),0,10000,label="SER moyenne: Bateau rectangulaire 7.5 x10",linestyle="--", color="blue")
plt.legend(fontsize=11)
plt.savefig("Resultats/SER_Rectangle.png",dpi=200,bbox_inches="tight")
plt.show()
np.mean(data_rectangle)
# Out:
# 2.6739204492525723

# %% [markdown]
# ## v3:

# %%
data_rectangle1=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_1p0.npy")
data_rectangle2=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_1p25.npy")
data_rectangle3=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_1p5.npy")
data_rectangle4=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_5x12.npy")

# %%
plt.figure(figsize=(10,3))
#plt.plot(omega/2/np.pi,data_carre, lw=3,label="Bateau carré: 10 m x 10 m", color="blue")
plt.plot(omega/2/np.pi,data_rectangle1,lw=3, ls="-", label="Bateau rectangulaire: 5 m x 10 m", color="orange",alpha=0.7)
#plt.plot(omega/2/np.pi,data_rectangle2,lw=3, ls="-", label="Bateau rectangulaire: 6.25 m x 10 m", color="blue")
plt.plot(omega/2/np.pi,data_rectangle3,lw=3, ls="-", label="Bateau rectangulaire: 7.5 m x 10 m", color="red", alpha=0.6)
plt.plot(omega/2/np.pi,data_rectangle4,lw=3, ls="-", label="Bateau rectangulaire: 5 m x 12 m", color="blue", alpha=0.6)
plt.xlabel("Fréquence (Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER (m$^2$)",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)

#plt.hlines(np.mean(data_carre),0,10000,label="SER moyen: Bateau carré",linestyle="--", color="blue")
plt.hlines(np.mean(data_rectangle1),0,10000,label="SER moyenne: 5 m x 10 m",linestyle="--",lw=4, color="orange")
plt.hlines(np.mean(data_rectangle3),0,10000,label="SER moyenne: 7.5 m x10 m",linestyle="--", color="red", alpha=0.8)
plt.hlines(np.mean(data_rectangle4),0,10000,label="SER moyenne: 5 m x12 m",linestyle="--", color="blue")
plt.legend(ncol=2,fontsize=10)
plt.savefig("Resultats/SER_Rectangle.png",dpi=200,bbox_inches="tight")
plt.show()
np.mean(data_rectangle1),np.mean(data_rectangle2),np.mean(data_rectangle4)
# Out:
# (1.896861189062249, 1.8874958984496932, 2.0896330568906207)

# %% [markdown]
# # Bateau pointe triangulaire

# %%
data_triangle1=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_triangle_pi4.npy")
data_triangle2=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_triangle_pi25.npy")

data_triangle3=np.load("Resultats/Matrices_Champ/SER/SERV2/SER_triangle_pi6.npy")

Dcm=23
L=5
coeff1=(Dcm-L*(1+1/2/np.tan(np.pi/8)))/(Dcm-(L/(12*np.tan(np.pi/8)*(4*np.tan(np.pi/8)+1))))
coeff1
coeff2=(Dcm-L*(1+1/2/np.tan(np.pi/5)))/(Dcm-(L/(12*np.tan(np.pi/5)*(4*np.tan(np.pi/5)+1))))
coeff2

coeff3=(Dcm-L*(1+1/2/np.tan(np.pi/12)))/(Dcm-(L/(12*np.tan(np.pi/12)*(4*np.tan(np.pi/12)+1))))


data_triangle1=data_triangle1*coeff1**3
data_triangle2=data_triangle2*coeff2**3
data_triangle3=data_triangle3*coeff3**3

# %%
plt.figure(figsize=(9,3))
plt.plot(omega/2/np.pi,data_triangle1, lw=3,label="Pointe triangulaire:$45\degree$", color="blue")
plt.plot(omega/2/np.pi,data_triangle2,lw=3, ls="-", label="Pointe triangulaire $75\degree$", color="red")
plt.plot(omega/2/np.pi,data_triangle3,lw=3, ls="-", label="Pointe triangulaire $30\degree$", color="orange")
plt.xlabel("Fréquence(Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
#plt.ylim(0,3.0)
plt.hlines(np.mean(data_triangle1),0,10000,label="SER moyenne: $45\degree$",linestyle="--", color="blue")
plt.hlines(np.mean(data_triangle2),0,10000,label="SER moyenne: $75\degree$",linestyle="--", color="red")
plt.hlines(np.mean(data_triangle3),0,10000,label="SER moyenne: $30\degree$",linestyle="--", color="orange")
plt.legend(ncol=2,fontsize=11)
plt.savefig("Resultats/SER_Triangle.png",dpi=200,bbox_inches="tight")
plt.show()

np.mean(data_triangle1),np.mean(data_triangle3)
# Out:
# (0.11031220162791629, 0.10228467068096357)

# %% [markdown]
# ## v3

# %%
data_triangle1=np.load("Resultats/Matrices_Champ/SERv3/SER3_triangle_pi3.npy")
data_triangle2=np.load("Resultats/Matrices_Champ/SERv3/SER3_triangle_pi4.npy")
data_triangle3=np.load("Resultats/Matrices_Champ/SERv3/SER3_triangle_pi5.npy")
data_triangle4=np.load("Resultats/Matrices_Champ/SERv3/SER3_triangle_2p25.npy")

# %%
plt.figure(figsize=(10,3))
plt.plot(omega/2/np.pi,data_triangle2,lw=3, ls="-", label="Pointe triangulaire $\pi/4$", color="orange")
plt.plot(omega/2/np.pi,data_triangle1, lw=3,label="Pointe triangulaire:$\pi/3$", color="blue",alpha=0.7)
#plt.plot(omega/2/np.pi,data_triangle3,lw=3, ls="-", label="Pointe triangulaire $36\degree$", color="orange")
plt.plot(omega/2/np.pi,data_triangle4,lw=3, ls="-", label="Pointe triangulaire $\pi/2.25$", color="red",alpha=0.8)
plt.xlabel("Fréquence (Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER (m$^2$)",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
#plt.ylim(0,3.0)
plt.hlines(np.mean(data_triangle2[:]),0,10000,label="SER moyenne: $\pi/4$",linestyle="--", color="orange")
plt.hlines(np.mean(data_triangle1[:]),0,10000,label="SER moyenne: $\pi/3$",linestyle="--", color="blue")
#plt.hlines(np.mean(data_triangle2[:]),0,10000,label="SER moyenne: $45\degree$",linestyle="--", color="red")
#plt.hlines(np.mean(data_triangle3),0,10000,label="SER moyenne: $36\degree$",linestyle="--", color="orange")
plt.hlines(np.mean(data_triangle4),0,10000,label="SER moyenne: $\pi/2.25$",linestyle="--", color="red")
plt.legend(ncol=2,fontsize=11)
plt.savefig("Resultats/SER_Triangle.png",dpi=200,bbox_inches="tight")
plt.show()

np.mean(data_triangle1),np.mean(data_triangle2),np.mean(data_triangle4)
# Out:
# (0.24187213618526077, 0.23368476128774934, 0.17827619575950598)

# %% [markdown]
# # Pointe circulaire:

# %%
data_cercle1=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_cercle_10.npy")
data_cercle2=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_cercle_15.npy")
data_cercle3=np.load("Resultats/Matrices_Champ/SER/SERV2/SER1001_cercle_22.npy")

len(omega)
# Out:
# 75

# %%
plt.figure(figsize=(9,3))
plt.plot(omega/2/np.pi,data_cercle1, lw=3,label="Rayon=$0.5\cdot$L", color="blue")
plt.plot(omega/2/np.pi,data_cercle2,lw=3, ls="-", label="Rayon=$0.75\cdot$ Largeur", color="orange")
#plt.plot(omega/2/np.pi,data_cercle3,lw=3, ls="-", label="Rayon=$1.1\cdot$ Largeur", color="blue")
plt.xlabel("Fréquence(Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
#plt.ylim(0,5.0)
#plt.hlines(np.mean(data_cercle1),0,10000,label="SER moyen:Rayon=$0.5\cdot$L",linestyle="--", color="blue")
plt.hlines(np.mean(data_cercle2),0,10000,label="SER moyenne: Rayon=$0.75\cdot$ Largeur",linestyle="--", color="orange")
plt.hlines(np.mean(data_cercle3),0,10000,label="SER moyenne: Rayon=$1.1\cdot$ Largeur",linestyle="--", color="blue")
plt.legend(ncol=2,fontsize=10.5)
plt.savefig("Resultats/SER_Cercle.png",dpi=200,bbox_inches="tight")
plt.show()

np.mean(data_cercle3),np.mean(data_cercle2)
# Out:
# (1.631189478559097, 0.5781005545668885)

# %% [markdown]
# ## v3

# %%
data_cercle1=np.load("Resultats/Matrices_Champ/SERv3/SER3_cercle_1p0.npy")
data_cercle2=np.load("Resultats/Matrices_Champ/SERv3/SER3_cercle_1p5.npy")
data_cercle3=np.load("Resultats/Matrices_Champ/SERv3/SER3_cercle_2p0.npy")

# %%
plt.figure(figsize=(10,3))
plt.plot(omega/2/np.pi,data_cercle1, lw=3,label="Rayon=$0.5\cdot$Largeur", color="red")
plt.plot(omega/2/np.pi,data_cercle2,lw=3, ls="-", label="Rayon=$0.75\cdot$ Largeur", color="orange")
plt.plot(omega/2/np.pi,data_cercle3,lw=3, ls="-", label="Rayon=$1.0\cdot$ Largeur", color="blue")
plt.xlabel("Fréquence (Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER (m$^2$)",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.ylim(0,3.0)
plt.hlines(np.mean(data_cercle1),0,10000,label="SER moyenne:Rayon=$0.5\cdot$Largeur",linestyle="--", color="red")
plt.hlines(np.mean(data_cercle2),0,10000,label="SER moyenne: Rayon=$0.75\cdot$ Largeur",linestyle="--", color="orange")
plt.hlines(np.mean(data_cercle3),0,10000,label="SER moyenne: Rayon=$1.0\cdot$ Largeur",linestyle="--", color="blue")
plt.legend(ncol=2,fontsize=10.0)
plt.savefig("Resultats/SER_Cercle.png",dpi=200,bbox_inches="tight")
plt.show()

np.mean(data_cercle1),np.mean(data_cercle2),np.mean(data_cercle3)
# Out:
# (1.0651986645993454, 0.7496377335005174, 0.7545512216267921)

# %% [markdown]
# # Comparaison de le SER en fonction du nombre de points

# %%
data_501=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_5x12_501.npy")
data_1001=np.load("Resultats/Matrices_Champ/SERv3/SER3_rectangle_5x12.npy")

# %%
plt.figure(figsize=(10,3))
plt.plot(omega/2/np.pi,0.27*data_501, lw=3,label="Nx=501", color="red")
plt.plot(omega/2/np.pi,data_1001,lw=3, ls="-", label="Nx=1001", color="orange")
plt.xlabel("Fréquence (Hz)",fontsize=12, fontweight="bold")
plt.ylabel("SER (m$^2$)",fontsize=12, fontweight="bold")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
#plt.ylim(0,3.0)
plt.hlines(np.mean(data_501),0,10000,label="SER moyenne:Nx=501",linestyle="--", color="red")
plt.hlines(np.mean(data_1001),0,10000,label="SER moyenne: Nx=1001",linestyle="--", color="orange")

plt.legend(ncol=2,fontsize=10.0)
#plt.savefig("Resultats/SER_Cercle.png",dpi=200,bbox_inches="tight")
plt.show()

np.mean(data_cercle1),np.mean(data_cercle2),np.mean(data_cercle3)
# Out:
# (1.0651986645993454, 0.7496377335005174, 0.7545512216267921)

# %% [markdown]
# # Sweep :Cercle
#
# ## source négative

# %%
coeff_arr=np.linspace(1.0, 4.0,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)


Results=np.load("Resultats/Matrices_Champ/SER/SERV2/Sweep_Cercle1a4.npy")
plt.figure(figsize=(8,8))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="hanning",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(coeff_arr,1),fontsize=12)
plt.ylabel("Rayon= Coeff*Largeur/2", fontsize=14)

plt.title("Log de la SER en fonction du coefficient \n du cercle et de la fréquence ", fontsize=12)

plt.show()

# %% [markdown]
# ## Source positive:

# %%
coeff_arr=np.linspace(1.0, 4.0,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)


Results=np.load("Resultats/Matrices_Champ/Sweep/Sweep_Cercle1a4_P_sourcepositive.npy")
plt.figure(figsize=(8,8))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="none",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(coeff_arr,1),fontsize=12)
plt.ylabel("Rayon= Coeff*Largeur/2", fontsize=14)

plt.title("Log de la SER en fonction du coefficient \n du cercle et de la fréquence ", fontsize=12)

plt.show()

# %% [markdown]
# ## Source positive alpha 0

# %%
coeff_arr=np.linspace(1.0, 4.0,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)


Results=np.load("Resultats/Matrices_Champ/Sweep/Sweep_Cercle1a4_P_sourcepos_alph0.npy")
plt.figure(figsize=(8,8))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="hanning",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(coeff_arr,1),fontsize=12)
plt.ylabel("Rayon= Coeff*Largeur/2", fontsize=14)

plt.title("Log de la SER en fonction du coefficient \n du cercle et de la fréquence ", fontsize=12)

plt.show()

# %% [markdown]
# # Sweep triangle
#
# ## Source négative

# %%
def Correction(alpha):
    Dcm=22.25
    L=5
    return (Dcm-L*(1+1/2/np.tan(alpha/2)))/(Dcm-(L/(12*np.tan(alpha/2)*(4*np.tan(alpha/2)+1))))

# %%
coeff_arr=np.linspace(np.pi/8, np.pi/1.1,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)



Results=np.load("Resultats/Matrices_Champ/SER/SERV2/Sweep_Trianglepi8api1p1v2.npy")
C2=np.transpose(Correction(coeff_arr)**2)
Results=np.transpose((C2*np.ones([50,16])))*Results
plt.figure(figsize=(7,7))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="none",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(np.rad2deg(coeff_arr)),fontsize=12)
plt.ylabel("Angle(deg)", fontsize=14)

plt.title("Log de la SER en fonction du angle \n du triangle et de la fréquence ", fontsize=12)

plt.show()

# %%
Correction(np.pi/8)**2
# Out:
# 0.049307727990090464

# %% [markdown]
# ## Source positive

# %%
coeff_arr=np.linspace(np.pi/8, np.pi/1.1,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)

Results=np.load("Resultats/Matrices_Champ/Sweep/Sweep_Trianglepi8api1p1v2_P_sourcepositive.npy")

C2=np.transpose(Correction(coeff_arr)**2)
Results=np.transpose((C2*np.ones([50,16])))*Results
plt.figure(figsize=(7,7))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="none",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(np.rad2deg(coeff_arr)),fontsize=12)
plt.ylabel("Angle(deg)", fontsize=14)

plt.title("Log de la SER en fonction du angle \n du triangle et de la fréquence ", fontsize=12)

plt.show()

# %%
coeff_arr=np.linspace(np.pi/8, np.pi/1.1,16)
omega_arr=2*np.pi*np.linspace(100,10000,50)


Results=np.load("Resultats/Matrices_Champ/Sweep/Sweep_Trianglepi8api1p1v2_P_sourcepos_alph0.npy")

C2=np.transpose(Correction(coeff_arr)**2)
Results=np.transpose((C2*np.ones([50,16])))*Results

plt.figure(figsize=(7,7))

plt.imshow(np.log10(np.array(Results)), cmap="jet",interpolation="none",aspect="auto")

plt.xticks(np.arange(0,omega_arr.shape[0],4),np.round(omega_arr[::4]/2/np.pi,),rotation=20)
plt.xlabel("Fréquence (Hz) ",fontsize=14)

plt.yticks(np.arange(coeff_arr.shape[0]),np.round(np.rad2deg(coeff_arr)),fontsize=12)
plt.ylabel("Angle(deg)", fontsize=14)

plt.title("Log de la SER en fonction du angle \n du triangle et de la fréquence ", fontsize=12)

plt.show()

# %%
# Correction Cercle 


def Correction_Cercle(coeff):
    # R_integration est en mètre
    Nx=1001
    Lx=40
    dx=Lx/Nx
    Nx_Bois=int(5/dx)
    coeff=coeff*Nx_Bois/2
    centre_bois_x=Nx/2
    centre_bois_y=1.3*Nx/2
    Sx=Nx/2
    Sy=75
    
    x_bois = centre_bois_x
    y_bois = centre_bois_y
    
    #Theta est l'anlge de l'arc du cercle
    theta = 2*np.arcsin(Nx_Bois/(2*coeff))
    x_cercle = centre_bois_x
    hauteur = coeff*(1-np.cos(coeff/2))
    #c est la distance entre le centre du cercle et le devant du bateau
    
    c = coeff-hauteur
    print(c*dx)
    y_cercle = centre_bois_y-Ny_Bois/2-((4*coeff*(np.sin(coeff/2))**3)/(3*(coeff-np.sin(coeff)))-c)
    x_bateau = centre_bois_x
    Aire_cercle = ((coeff**2)/2)*(coeff-np.sin(coeff))
    print(Aire_cercle*dx**2)
    y_bateau = (centre_bois_y*Ny_Bois*Nx_Bois+y_cercle*Aire_cercle)/(Ny_Bois*Nx_Bois+Aire_cercle)
    


    Distance_bateau_bois1=np.sqrt((Sx-x_bateau)**2+(Sy-y_bateau)**2)*dx
    Distance_bateau_bois2=np.sqrt((Sx-centre_bois_x)**2+(Sy-centre_bois_y)**2)*dx- c*dx-Nx_Bois*dx
    print(Distance_bateau_bois1)
    print(Distance_bateau_bois2)
    return Distance_bateau_bois2/Distance_bateau_bois1

# %%
Correction_Cercle(1.6)
# Out:
# 3.9910200024416462
# 802.4452322192074
# 19.801129740934766
# 14.016972005550361
# 0.7078874886907666
